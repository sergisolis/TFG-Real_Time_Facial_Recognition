# %%
import matplotlib.pyplot as plt
import pickle
import os

plt.figure(figsize=(12, 6))

for filename in os.listdir('cross_entropy_history'):  
    if filename.endswith(".pkl"):
        with open('cross_entropy_history/' + filename, 'rb') as f:
            history = pickle.load(f)
        plt.plot(history['loss'], label=f'{filename} training')
        plt.plot(history['val_loss'], label=f'{filename} validation')


plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(loc='upper right')
plt.show()
